# %% [markdown]
# # SoundLib
# An online music library

# %% [markdown]
# ## Features
# - Top Charts
# - Chart Analyis
# - Track Detail
# - Album Details
# - Artist Details
# - Search

# %% [markdown]
# ## Functions
# - get_spotify_instance - Connect to Spotify
# - get_playlist_tracks - Get Tracks belonging to Playlist
# - get_artist_details - Get Artist Details
# - get_artist_top_tracks - Get Top Tracks for an Artist
# - get_album_details - Get Album Details including related Artists and Tracks
# - get_track_details - Get Track Details including Related Artists
# - get_audio_features - Get Audio Features for further analysis
# - spotify_search - Search Spotify for Track / Artist / Album

# %%
# Import the necessary modules
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def get_spotify_instance():
    """Creates a connection to Spotify API and returns an instance of Spotify class"""
    
    # Set up credentials by obtaining a client ID and client secret from the Spotify Developer Dashboard
    client_id = '37a0f04e90f54ea38ff06ba7473d8ffd'
    client_secret = 'd904795e86c5486da53db07dd05991ac'
    
    # Create an instance of the spotipy.Spotify class and authenticate using credentials
    auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    spotify_instance = spotipy.Spotify(auth_manager=auth_manager)
    
    return spotify_instance

# %%
def get_playlist_tracks(playlist_id, spotify_instance, limit=None):
    """Fetches the track ids based on the playlist id. Returns a list of dictionaries of playlist details"""

    # Fetch the json data using Spotify API

    results = spotify_instance.playlist_items(playlist_id, limit=limit)

    # Create empty list to store the extracted information
    track_ids = []

    # Iterate over the playlist items and extract the track ids
    for item in results['items']:
        track1 = item['track']
        track_dict = {"ID": track1["id"], "Name": track1["name"],
                      "Duration": milliseconds_to_min_sec(track1["duration_ms"]), "Artists": [],
                      "AlbumID": track1["album"]["id"], "Image": track1["album"]["images"][2]["url"]}
        ctr = 0
        for artist1 in track1["artists"]:
            track_dict["Artists"].append((artist1["id"], artist1["name"]))
            ctr += 1
        if ctr == 1:
            track_dict["Artists"] = (track1["artists"][0]["id"], track1["artists"][0]["name"])
        track_ids.append(track_dict)

    return track_ids

# %%
sp = get_spotify_instance()
playlist_id="37i9dQZEVXbMDoHDwVN2tF"
playlist_tracks = get_playlist_tracks(playlist_id, sp)
playlist_tracks

for track in playlist_tracks:
    print(track["Artists"])
# Out:
# [('6HaGTQPmzraVmaVxvz6EUc', 'Jung Kook'), ('3MdXrJWsbVzdn6fe5JYkSQ', 'Latto')]
# ('5cj0lLjcoR7YOSnhnX0Po5', 'Doja Cat')
# ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift')
# ('7iK8PXO48WeuP03g8YR51W', 'Myke Towers')
# [('790FomKkXshlbRYZFtlgla', 'KAROL G'), ('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma')]
# ('6M2wZ9GZgrQXHCFfjv46we', 'Dua Lipa')
# ('52iwsT98xCoGgiGntTiR7K', 'Quevedo')
# ('6qqNVTkY8uBg9cP3Jd7DAH', 'Billie Eilish')
# ('1McMsnEElThX1knmY4oliG', 'Olivia Rodrigo')
# ('2hlmm7s2ICUX0LVIhVFlZQ', 'Gunna')
# [('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma'), ('6Sbl0NT50roqWvy746MfVf', 'Gabito Ballesteros'), ('7Gi6gjaWy3DxyilpF1a8Is', 'Junior H')]
# [('6Ip8FS7vWT1uKkJSweANQK', 'Dave'), ('5H4yInM5zmHqpKIoMNAx4r', 'Central Cee')]
# [('0hCNtLu0JehylgoiP8L4Gh', 'Nicki Minaj'), ('3LZZPxNDGDFVSIPqf4JuEf', 'Ice Spice'), ('6kBjAFKyd0he7LiA5GQ3Gz', 'Aqua')]
# ('5YGY8feqx7naU7z4HrwZM6', 'Miley Cyrus')
# ('33NVpKoXjItPwUJTMZIOiY', 'David Kushner')
# ('6KImCVD70vtIoJWnq6nGn3', 'Harry Styles')
# [('1NNRWkhwmcXRimFYSBpB1y', 'Yng Lvcas'), ('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma')]
# ('4q3ewBCX7sLwd24euuV69X', 'Bad Bunny')
# [('2LRoIwlKmHjgvigdNGBHNo', 'Feid'), ('3qsKSpcV3ncke3hw52JSMB', 'Young Miko')]
# ('66ihevNkSYNzRAl44dx6jJ', 'Carin Leon')
# ('7tYKF4w9nC0nq9CsPZTHyP', 'SZA')
# ('6HvZYsbFfjnjFrWF950C9d', 'NewJeans')
# ('790FomKkXshlbRYZFtlgla', 'KAROL G')
# ('2mLA48B366zkELXYx7hcDN', 'Peggy Gou')
# ('7Ln80lUS6He07XvHI8qqHH', 'Arctic Monkeys')
# [('0XeEobZplHxzM9QzFQWLiR', 'Eslabon Armado'), ('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma')]
# ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift')
# ('6nVcHLIgY5pE2YCl8ubca1', 'Jhayco')
# [('40ZNYROS4zLfyyBSs2PGe2', 'Zach Bryan'), ('70kkdajctXSbqSMJbQO424', 'Kacey Musgraves')]
# ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift')
# ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift')
# [('1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd'), ('699OTQXzgjhIYAHMy9RyPD', 'Playboi Carti'), ('6tbjWDEIzxoDsBA1FuhfPW', 'Madonna')]
# [('74OaRjmyh0XyRZsQQQ5l7c', 'Jasleen Royal'), ('4YRxDV8wJFPHPTeXepOstw', 'Arijit Singh'), ('3NHwwyb1coYa5cLyI72xSk', 'Dulquer Salmaan')]
# ('1McMsnEElThX1knmY4oliG', 'Olivia Rodrigo')
# [('6XkjpgcEsYab502Vr1bBeW', 'Grupo Frontera'), ('4q3ewBCX7sLwd24euuV69X', 'Bad Bunny')]
# [('5wCmhq5J2hPwL2r0eKurxn', 'cassö'), ('5KKpBU5eC2tJDzf0wmlRp2', 'RAYE'), ('5VadK1havLhK1OpKYsXv9y', 'D-Block Europe')]
# ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift')
# ('5YGY8feqx7naU7z4HrwZM6', 'Miley Cyrus')
# [('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma'), ('6XkjpgcEsYab502Vr1bBeW', 'Grupo Frontera')]
# [('6dLuQ5qXxIuWc5urxfIiZR', 'Calle 24'), ('2rmkQLzj0k4nZdQehOUByO', 'Chino Pacas'), ('0ys2OFYzWYB5hRDLCsBqxt', 'Fuerza Regida')]
# [('1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd'), ('4tZwfgrHOc3mvqYlEYSvVi', 'Daft Punk')]
# [('46pWGuE3dSwY3bMMXGBvVS', 'Rema'), ('0C8ZW7ezQVs4URX5aX7Kqx', 'Selena Gomez')]
# ('3JsHnjpbhX4SnySpvpa9DK', 'V')
# ('1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd')
# ('4oUHIQIBe0LHzYfvXNW4QM', 'Morgan Wallen')
# ('1oSPZhvZMIrWW5I41kPkkY', 'Jimin')
# ('0ys2OFYzWYB5hRDLCsBqxt', 'Fuerza Regida')
# ('0Y5tJX1MQlPlqiwlOH1tJY', 'Travis Scott')
# ('4GJ6xDCF5jaUqD6avOuQT6', 'FIFTY FIFTY')
# [('0iEtIxbK0KxaSlF7G42ZOp', 'Metro Boomin'), ('1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd'), ('1URnnhqYAYcrqrcwql10ft', '21 Savage')]

# %%
def get_artist_details(artist_id, spotify_instance):
    """Fetches the artist details based on artist id. Returns a dictionary of artist details"""
    
    # Fetch the json data using Spotify API
    results = spotify_instance.artist(artist_id)
    
    # Create empty dictionary to store the extracted information
    artist_details = {}
    
    # Extract the relevant information
    artist_details["ID"] = artist_id
    artist_details["Name"] = results["name"]
    artist_details["Popularity"] = results["popularity"]
    artist_details["Followers"] = results["followers"]["total"]
    artist_details["Genres"] = results["genres"]
    artist_details["URL"] = results["external_urls"]["spotify"]
    artist_details["Images"] = results["images"]
    
    return artist_details

# %%
def get_album_details(album_id, spotify_instance):
    """Fetches the album details based on album id. Returns a dictionary of album details"""
    
    # Fetch the json data using Spotify API
    results = spotify_instance.album(album_id)
    
    # Create empty dictionary to store the extracted information
    album_details = {}
    
    # Extract the relevant information
    album_details["ID"] = album_id
    album_details["Name"] = results["name"]
    album_details["Type"] = results["album_type"]
    album_details["Artists"] = []
    ctr=0
    for artist in results["artists"]:
        album_details["Artists"].append((artist["id"], artist["name"]))
        ctr += 1
    if ctr == 1:
        album_details["Artists"] = (results["artists"][0]["id"], results["artists"][0]["name"])
    album_details["Label"] = results["label"]
    album_details["Release date"] = results["release_date"]
    album_details["Total Tracks"] = results["total_tracks"]
    album_details["Popularity"] = results["popularity"]
    album_details["Genres"] = results["genres"]
    album_details["URL"] = results["external_urls"]["spotify"]
    album_details["Images"] = results["images"]
    album_details["Tracks"] = []
    ctr=0
    for track in results["tracks"]["items"]:
        album_details["Tracks"].append((track["id"], track["name"]))
        ctr += 1
    if ctr == 1:
        album_details["Tracks"] = (results["tracks"]["items"][0]["id"], results["tracks"]["items"][0]["name"])
    
    return album_details

# %%
def get_track_details(track_id, spotify_instance):
    """Fetches the track details based on track id. Returns a dictionary of track details"""
    
    # Fetch the json data using Spotify API
    results = spotify_instance.track(track_id)
    
    # Create empty dictionary to store the extracted information
    track_details = {}
    
    # Extract the relevant information
    track_details["ID"] = track_id
    track_details["Name"] = results["name"]
    track_details["Artists"] = []
    ctr=0
    for artist in results["artists"]:
        track_details["Artists"].append((artist["id"], artist["name"]))
        ctr += 1
    if ctr == 1:
        track_details["Artists"] = (results["artists"][0]["id"], results["artists"][0]["name"])
    track_details["Album Name"] = results["album"]["name"]
    track_details["Album ID"] = results["album"]["id"]
    track_details["Duration"] = results["duration_ms"]
    track_details["Popularity"] = results["popularity"]
    track_details["URL"] = results["external_urls"]["spotify"]
    track_details["Images"] = results["album"]["images"]
    
    return track_details

# %%
def get_artist_top_tracks(artist_id, spotify_instance):
    """Fetches the top tracks based on the artist id. Returns a list of tuples of track ids and track name"""
    
    # Fetch the json data using Spotify API
    results = spotify_instance.artist_top_tracks(artist_id)
    
    # Create empty list to store the extracted information
    track_ids = []
    
    # Iterate over the top tracks data and extract the track ids
    for track in results['tracks']:
        track_ids.append((track['id'],track['name']))
    
    return track_ids

# %%
def get_audio_features(track_ids, spotify_instance):
    """Fetches the track audio features based on track ids. Returns a list of dictionaries of track audio features"""

    # Fetch the json data using Spotify API
    results = spotify_instance.audio_features(track_ids)

    # Create empty list to store the extracted information
    tracks_audio_features = []

    # Extract the relevant information
    for af_track in results:
        taf_dict = {"Track ID": af_track["id"], "Danceability": af_track["danceability"], "Energy": af_track["energy"],
                    "Tempo": af_track["tempo"], "Valence": af_track["valence"]}
        tracks_audio_features.append(taf_dict)

    return tracks_audio_features

# %%
def get_playlist_artists(playlist_id, spotify_instance, limit=None):
    """Fetches the artists names based on the playlist id. Returns a list of dictionaries of artist names"""

    # Fetch the json data using Spotify API

    results = spotify_instance.playlist_items(playlist_id, limit=limit)

    # Create empty list to store the extracted information
    artist_names = []

    # Iterate over the playlist items and extract the track ids
    for item in results['items']:
        track2 = item['track']
        for artist2 in track2["artists"]:
            artist_names.append(artist2["name"])

    return artist_names

# %%
sp = get_spotify_instance()
playlist_id_global = "37i9dQZEVXbMDoHDwVN2tF"
playlist_id_sweden = "37i9dQZEVXbLoATJ81JYXz"
global_artists = get_playlist_artists(playlist_id_global,sp)
df_global_artists = pd.DataFrame(global_artists, columns=["Artist"])
df_global_artists.value_counts()[value_counts > 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       4 global_artists = get_playlist_artists(playlist_id_global,sp)
#       5 df_global_artists = pd.DataFrame(global_artists, columns=["Artist"])
# ----> 6 df_global_artists.value_counts()[value_counts > 1]
#
# NameError: name 'value_counts' is not defined

# %%
sweden_artists = get_playlist_artists(playlist_id_sweden,sp)
df_sweden_artists = pd.DataFrame(sweden_artists, columns=["Artist"])
svalue_counts = df_sweden_artists.value_counts().reset_index()
svalue_counts.columns = ['Artist', '# of Songs']
svalue_counts = svalue_counts.loc[svalue_counts["# of Songs"] > 1]
plt.figure(figsize=(4, 3))
plt.title('Artists with most songs on Sweden Top 50')
ax = sns.barplot(y='Artist', x='# of Songs', data=svalue_counts)
for index, value in enumerate(svalue_counts["# of Songs"]):
    ax.text(value, index, str(value), color='black', ha="left", va="center", fontsize=10)
plt.show()

# %%
global_artists = get_playlist_artists(playlist_id_global,sp)
df_global_artists = pd.DataFrame(global_artists, columns=["Artist"])
gvalue_counts = df_global_artists.value_counts().reset_index()
gvalue_counts.columns = ['Artist', '# of Songs']
gvalue_counts = gvalue_counts.loc[gvalue_counts["# of Songs"] > 1]
plt.figure(figsize=(4, 3))
plt.title('Artists with most songs on Global Top 50')
ax = sns.barplot(y='Artist', x='# of Songs', data=gvalue_counts)
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 3))

ax1 =sns.barplot(y='Artist', x='# of Songs', data=gvalue_counts, ax=axes[0])
axes[0].set_title('Global')
for index, value in enumerate(gvalue_counts["# of Songs"]):
    ax1.text(value, index, str(value), color='black', ha="left", va="center", fontsize=10)

ax2= sns.barplot(y='Artist', x='# of Songs', data=svalue_counts, ax=axes[1])
axes[1].set_title('Sweden')
for index, value in enumerate(svalue_counts["# of Songs"]):
    ax2.text(value, index, str(value), color='black', ha="left", va="center", fontsize=10)
    
fig.suptitle('Top Artists in Top 50 Songs', fontsize=16, y=1.05)

plt.tight_layout()
plt.show()

# %%
def spotify_search(search_text, search_type, spotify_instance):
    """Fetches the search results based on search text. Returns a list of dictionaries of artists / albums / tracks"""
    
    # Fetch the json data using Spotify API
    results = spotify_instance.search(search_text, type=search_type, limit=10)
    
    # Create empty list to store the extracted information
    search_results = []
    
    # Extract the relevant information
    search_type = search_type + "s"
    for result in results[search_type]["items"]:
        result_dict = {}
        result_dict["ID"] = result["id"]
        result_dict["Name"] = result["name"]
        search_results.append(result_dict)
        
    return search_results

# %%
def milliseconds_to_min_sec(ms):
    # Convert milliseconds to total seconds
    total_seconds = ms // 1000

    # Divide total seconds to get minutes and seconds
    minutes = total_seconds // 60
    seconds = total_seconds % 60

    return f"{minutes}:{seconds:02}"

# %%
sp = get_spotify_instance()
search_text = "Michael Jackson"
search_type="artist"
results = sp.search(search_text, type=search_type, limit=10)

results
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Michael+Jackson&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DsOlo169ovaAx19956vOb'},
#     'followers': {'href': None, 'total': 3858},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1DsOlo169ovaAx19956vOb',
#     'id': '1DsOlo169ovaAx19956vOb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb529283cec641d43f9839ad61',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174529283cec641d43f9839ad61',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178529283cec641d43f9839ad61',
#       'width': 160}],
#     'name': 'MikeJack3200',
#     'popularity': 32,
#     'type': 'artist',
#     'uri': 'spotify:artist:1DsOlo169ovaAx19956vOb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7LI0TvOBQdTaOMBsywCk1u'},
#     'followers': {'href': None, 'total': 2},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7LI0TvOBQdTaOMBsywCk1u',
#     'id': '7LI0TvOBQdTaOMBsywCk1u',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb21096a962a3e7e06481ab6e0',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517421096a962a3e7e06481ab6e0',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17821096a962a3e7e06481ab6e0',
#       'width': 160}],
#     'name': 'Jackson Michael',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:7LI0TvOBQdTaOMBsywCk1u'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#     'followers': {'href': None, 'total': 28559245},
#     'genres': ['r&b', 'soul'],
#     'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#     'id': '3fMbdgg4jU18AjLCKBhRSm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb0e08ea2c4d6789fbf5cbe0aa',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051740e08ea2c4d6789fbf5cbe0aa',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1780e08ea2c4d6789fbf5cbe0aa',
#       'width': 160}],
#     'name': 'Michael Jackson',
#     'popularity': 80,
#     'type': 'artist',
#     'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2XKBOnP3qXHP2FpzKplAYh'},
#     'followers': {'href': None, 'total': 102900},
#     'genres': ['soft rock'],
#     'href': 'https://api.spotify.com/v1/artists/2XKBOnP3qXHP2FpzKplAYh',
#     'id': '2XKBOnP3qXHP2FpzKplAYh',
#     'images': [{'height': 900,
#       'url': 'https://i.scdn.co/image/eb9e5a64eb02e387f8b176179dc1779c42dc9a6e',
#       'width': 602},
#      {'height': 299,
#       'url': 'https://i.scdn.co/image/e27803dd5b82ded4b64f89df4f71e2cace59f49e',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/1e4779e2d60b724f85be382123f9af6f9830deaf',
#       'width': 64}],
#     'name': 'Michael Johnson',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:2XKBOnP3qXHP2FpzKplAYh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2mFrm3KGmRhW62fnDeyhAW'},
#     'followers': {'href': None, 'total': 306},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2mFrm3KGmRhW62fnDeyhAW',
#     'id': '2mFrm3KGmRhW62fnDeyhAW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb630479b22f6b59dc1d9f10e3',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174630479b22f6b59dc1d9f10e3',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178630479b22f6b59dc1d9f10e3',
#       'width': 160}],
#     'name': 'Mikayla Jackson',
#     'popularity': 27,
#     'type': 'artist',
#     'uri': 'spotify:artist:2mFrm3KGmRhW62fnDeyhAW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5uE0DYHyEKWVu9aUid7EJg'},
#     'followers': {'href': None, 'total': 84},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5uE0DYHyEKWVu9aUid7EJg',
#     'id': '5uE0DYHyEKWVu9aUid7EJg',
#     'images': [],
#     'name': 'Michael Joseph Jackson',
#     'popularity': 8,
#     'type': 'artist',
#     'uri': 'spotify:artist:5uE0DYHyEKWVu9aUid7EJg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Q3aSZGYDiFjmeoilPa8zE'},
#     'followers': {'href': None, 'total': 884},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4Q3aSZGYDiFjmeoilPa8zE',
#     'id': '4Q3aSZGYDiFjmeoilPa8zE',
#     'images': [],
#     'name': 'Michael Jackson For Siegfried',
#     'popularity': 5,
#     'type': 'artist',
#     'uri': 'spotify:artist:4Q3aSZGYDiFjmeoilPa8zE'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7laaeJcmU9FPO4OdhFelEN'},
#     'followers': {'href': None, 'total': 5985},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7laaeJcmU9FPO4OdhFelEN',
#     'id': '7laaeJcmU9FPO4OdhFelEN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eba244bd73d4429d7cc89b7dc3',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174a244bd73d4429d7cc89b7dc3',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178a244bd73d4429d7cc89b7dc3',
#       'width': 160}],
#     'name': 'David Michael Jackson',
#     'popularity': 17,
#     'type': 'artist',
#     'uri': 'spotify:artist:7laaeJcmU9FPO4OdhFelEN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MR0a6Lp2tRxEjm4gdNiaO'},
#     'followers': {'href': None, 'total': 502},
#     'genres': ['broadway'],
#     'href': 'https://api.spotify.com/v1/artists/2MR0a6Lp2tRxEjm4gdNiaO',
#     'id': '2MR0a6Lp2tRxEjm4gdNiaO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb5353fb743c3c2b791ee6d610',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051745353fb743c3c2b791ee6d610',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1785353fb743c3c2b791ee6d610',
#       'width': 160}],
#     'name': 'Michael R. Jackson',
#     'popularity': 14,
#     'type': 'artist',
#     'uri': 'spotify:artist:2MR0a6Lp2tRxEjm4gdNiaO'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4zezrdpMUW17jmU9HirJ7E'},
#     'followers': {'href': None, 'total': 24},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4zezrdpMUW17jmU9HirJ7E',
#     'id': '4zezrdpMUW17jmU9HirJ7E',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c481c2d2fef94b07eddefd6b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a57ea99110bba5624d5bd7cf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a57ea99110bba5624d5bd7cf',
#       'width': 64}],
#     'name': 'Michael Jackson',
#     'popularity': 3,
#     'type': 'artist',
#     'uri': 'spotify:artist:4zezrdpMUW17jmU9HirJ7E'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Michael+Jackson&type=artist&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 233}}

# %%
sp = get_spotify_instance()    
playlist_id_global = "37i9dQZEVXbMDoHDwVN2tF"
playlist_tracks_global = get_playlist_tracks(playlist_id_global, sp)
playlist_id_sweden = "37i9dQZEVXbLoATJ81JYXz"
playlist_tracks_sweden = get_playlist_tracks(playlist_id_sweden, sp)
playlist_tracks_global
# Out:
# [{'ID': '7x9aauaA9cu6tyfpHnqDLo',
#   'Name': 'Seven (feat. Latto) (Explicit Ver.)',
#   'Duration': '3:04',
#   'Artists': [('6HaGTQPmzraVmaVxvz6EUc', 'Jung Kook'),
#    ('3MdXrJWsbVzdn6fe5JYkSQ', 'Latto')],
#   'AlbumID': '53985D8g3JcGBoULSOYYKX',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851bf5cce5a0e1ed03a626bdd74'},
#  {'ID': '2IGMVunIBsBLtEQyoI1Mu7',
#   'Name': 'Paint The Town Red',
#   'Duration': '3:51',
#   'Artists': ('5cj0lLjcoR7YOSnhnX0Po5', 'Doja Cat'),
#   'AlbumID': '54dZypaXHAIDzBe9ujAZ63',
#   'Image': 'https://i.scdn.co/image/ab67616d000048517acee948ecac8380c1b6ce30'},
#  {'ID': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'Name': 'Cruel Summer',
#   'Duration': '2:58',
#   'Artists': ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift'),
#   'AlbumID': '1NAmidJlEaVgA3MpcPFYGq',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647'},
#  {'ID': '7ABLbnD53cQK00mhcaOUVG',
#   'Name': 'LALA',
#   'Duration': '3:17',
#   'Artists': ('7iK8PXO48WeuP03g8YR51W', 'Myke Towers'),
#   'AlbumID': '3puAvurwvtvi1rodndIPW8',
#   'Image': 'https://i.scdn.co/image/ab67616d000048510656d5ce813ca3cc4b677e05'},
#  {'ID': '5RqSsdzTNPX1uzkmlHCFvK',
#   'Name': 'QLONA',
#   'Duration': '2:52',
#   'Artists': [('790FomKkXshlbRYZFtlgla', 'KAROL G'),
#    ('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma')],
#   'AlbumID': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851d026bf9d7780f6a1267b4d03'},
#  {'ID': '6wf7Yu7cxBSPrRlWeSeK0Q',
#   'Name': 'What Was I Made For? [From The Motion Picture "Barbie"]',
#   'Duration': '3:42',
#   'Artists': ('6qqNVTkY8uBg9cP3Jd7DAH', 'Billie Eilish'),
#   'AlbumID': '3AafSrFIbJPH6BJHiJm1Cd',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851ed317ec13d3de9e01fb99c9e'},
#  {'ID': '1vYXt7VSjH9JIM5oRRo7vA',
#   'Name': 'Dance The Night - From Barbie The Album',
#   'Duration': '2:56',
#   'Artists': ('6M2wZ9GZgrQXHCFfjv46we', 'Dua Lipa'),
#   'AlbumID': '5cH7FqB7JD5q1tJXJ7FHYu',
#   'Image': 'https://i.scdn.co/image/ab67616d000048517dd3ba455ee3390cb55b0192'},
#  {'ID': '6XbtvPmIpyCbjuT0e8cQtp',
#   'Name': 'Columbia',
#   'Duration': '3:06',
#   'Artists': ('52iwsT98xCoGgiGntTiR7K', 'Quevedo'),
#   'AlbumID': '07kam1Dks7GIucbSelfvyX',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851a00a817b017c6f6bf8460be9'},
#  {'ID': '3k79jB4aGmMDUQzEwa46Rz',
#   'Name': 'vampire',
#   'Duration': '3:39',
#   'Artists': ('1McMsnEElThX1knmY4oliG', 'Olivia Rodrigo'),
#   'AlbumID': '5kqfR7EuGbyp8x27Pr1kY9',
#   'Image': 'https://i.scdn.co/image/ab67616d000048511e5e75dc1d878a0007cb6525'},
#  {'ID': '4rXLjWdF2ZZpXCVTfWcshS',
#   'Name': 'fukumean',
#   'Duration': '2:05',
#   'Artists': ('2hlmm7s2ICUX0LVIhVFlZQ', 'Gunna'),
#   'AlbumID': '5qmZefgh78fN3jsyPPlvuw',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851017d5e26552345c4b1575b6c'},
#  {'ID': '7mXuWTczZNxG5EDcjFEuJR',
#   'Name': 'LADY GAGA',
#   'Duration': '3:32',
#   'Artists': [('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma'),
#    ('6Sbl0NT50roqWvy746MfVf', 'Gabito Ballesteros'),
#    ('7Gi6gjaWy3DxyilpF1a8Is', 'Junior H')],
#   'AlbumID': '4jox3ip1I39DFC2B7R5qLH',
#   'Image': 'https://i.scdn.co/image/ab67616d000048512fb583ed96f8f35cbf2897ba'},
#  {'ID': '1odExI7RdWc4BT515LTAwj',
#   'Name': 'Daylight',
#   'Duration': '3:32',
#   'Artists': ('33NVpKoXjItPwUJTMZIOiY', 'David Kushner'),
#   'AlbumID': '6NcI39WPu4kY6Tul11nhSv',
#   'Image': 'https://i.scdn.co/image/ab67616d0000485195ca6a9b4083a86c149934ae'},
#  {'ID': '2FDTHlrBguDzQkp7PVj16Q',
#   'Name': 'Sprinter',
#   'Duration': '3:49',
#   'Artists': [('6Ip8FS7vWT1uKkJSweANQK', 'Dave'),
#    ('5H4yInM5zmHqpKIoMNAx4r', 'Central Cee')],
#   'AlbumID': '5l0QlaI3wdZpE7ggoO5Rwg',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851e3a09a9ae3f1fa102c110e60'},
#  {'ID': '5sdQOyqq2IDhvmx2lHOpwd',
#   'Name': 'Super Shy',
#   'Duration': '2:34',
#   'Artists': ('6HvZYsbFfjnjFrWF950C9d', 'NewJeans'),
#   'AlbumID': '5V729UqvhwNOcMejx0m55I',
#   'Image': 'https://i.scdn.co/image/ab67616d000048513d98a0ae7c78a3a9babaf8af'},
#  {'ID': '741UUVE2kuITl0c6zuqqbO',
#   'Name': 'Barbie World (with Aqua) [From Barbie The Album]',
#   'Duration': '1:49',
#   'Artists': [('0hCNtLu0JehylgoiP8L4Gh', 'Nicki Minaj'),
#    ('3LZZPxNDGDFVSIPqf4JuEf', 'Ice Spice'),
#    ('6kBjAFKyd0he7LiA5GQ3Gz', 'Aqua')],
#   'AlbumID': '5CM66hwjlbZ06LhONWXOAs',
#   'Image': 'https://i.scdn.co/image/ab67616d000048517e8f938c02fac3b564931116'},
#  {'ID': '5XeFesFbtLpXzIVDNQP22n',
#   'Name': 'I Wanna Be Yours',
#   'Duration': '3:03',
#   'Artists': ('7Ln80lUS6He07XvHI8qqHH', 'Arctic Monkeys'),
#   'AlbumID': '78bpIziExqiI9qztvNFlQu',
#   'Image': 'https://i.scdn.co/image/ab67616d000048514ae1c4c5c45aabe565499163'},
#  {'ID': '1Qrg8KqiBpW07V7PNxwwwL',
#   'Name': 'Kill Bill',
#   'Duration': '2:33',
#   'Artists': ('7tYKF4w9nC0nq9CsPZTHyP', 'SZA'),
#   'AlbumID': '1nrVofqDRs7cpWXJ49qTnP',
#   'Image': 'https://i.scdn.co/image/ab67616d000048510c471c36970b9406233842a5'},
#  {'ID': '4Dvkj6JhhA12EX05fT7y2e',
#   'Name': 'As It Was',
#   'Duration': '2:47',
#   'Artists': ('6KImCVD70vtIoJWnq6nGn3', 'Harry Styles'),
#   'AlbumID': '5r36AJ6VOJtp00oxSkBZ5h',
#   'Image': 'https://i.scdn.co/image/ab67616d000048512e8ed79e177ff6011076f5f0'},
#  {'ID': '4DHcnVTT87F0zZhRPYmZ3B',
#   'Name': 'Flowers',
#   'Duration': '3:20',
#   'Artists': ('5YGY8feqx7naU7z4HrwZM6', 'Miley Cyrus'),
#   'AlbumID': '0HiZ8fNXwJOQcrf5iflrdz',
#   'Image': 'https://i.scdn.co/image/ab67616d0000485158039b5147731b6e52202e46'},
#  {'ID': '25OeKzcqakFPaJlXHPE5lm',
#   'Name': 'Primera Cita',
#   'Duration': '3:06',
#   'Artists': ('66ihevNkSYNzRAl44dx6jJ', 'Carin Leon'),
#   'AlbumID': '52PtAAvfi8ZGTRK5c700y4',
#   'Image': 'https://i.scdn.co/image/ab67616d000048510e30fcf494fd711ad068d1cd'},
#  {'ID': '2UW7JaomAMuX9pZrjVpHAU',
#   'Name': 'La Bebe - Remix',
#   'Duration': '3:54',
#   'Artists': [('1NNRWkhwmcXRimFYSBpB1y', 'Yng Lvcas'),
#    ('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma')],
#   'AlbumID': '6aBVGuOUEuX18rHxyDWbti',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851a04be3ad7c8c67f4109111a9'},
#  {'ID': '7ro0hRteUMfnOioTFI5TG1',
#   'Name': 'WHERE SHE GOES',
#   'Duration': '3:51',
#   'Artists': ('4q3ewBCX7sLwd24euuV69X', 'Bad Bunny'),
#   'AlbumID': '5gCcb5fsSb6w5K8SyJrgtB',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851ab5c9cd818ad6ed3e9b79cd1'},
#  {'ID': '5PUXKVVVQ74C3gl5vKy9Li',
#   'Name': 'Heeriye (feat. Arijit Singh)',
#   'Duration': '3:14',
#   'Artists': [('74OaRjmyh0XyRZsQQQ5l7c', 'Jasleen Royal'),
#    ('4YRxDV8wJFPHPTeXepOstw', 'Arijit Singh'),
#    ('3NHwwyb1coYa5cLyI72xSk', 'Dulquer Salmaan')],
#   'AlbumID': '1wt2WZBZZ9GhM0AC61l7SS',
#   'Image': 'https://i.scdn.co/image/ab67616d0000485102ea9d69484ed871c3e34bea'},
#  {'ID': '6XSqqQIy7Lm7SnwxS4NrGx',
#   'Name': 'Classy 101',
#   'Duration': '3:15',
#   'Artists': [('2LRoIwlKmHjgvigdNGBHNo', 'Feid'),
#    ('3qsKSpcV3ncke3hw52JSMB', 'Young Miko')],
#   'AlbumID': '4jtQUtS4ABgER3DnGfKJCv',
#   'Image': 'https://i.scdn.co/image/ab67616d0000485129ebee2b5fb008871fcd201a'},
#  {'ID': '3hUxzQpSfdDqwM3ZTFQY0K',
#   'Name': 'august',
#   'Duration': '4:21',
#   'Artists': ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift'),
#   'AlbumID': '2fenSS68JI1h4Fo296JfGr',
#   'Image': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc'},
#  {'ID': '23RoR84KodL5HWvUTneQ1w',
#   'Name': '(It Goes Like) Nanana - Edit',
#   'Duration': '3:51',
#   'Artists': ('2mLA48B366zkELXYx7hcDN', 'Peggy Gou'),
#   'AlbumID': '2LVDNOUUy2g8517ZEtQIcK',
#   'Image': 'https://i.scdn.co/image/ab67616d000048519a8459318ff1a68ecfd74522'},
#  {'ID': '4KULAymBBJcPRpk1yO4dOG',
#   'Name': 'I Remember Everything (feat. Kacey Musgraves)',
#   'Duration': '3:47',
#   'Artists': [('40ZNYROS4zLfyyBSs2PGe2', 'Zach Bryan'),
#    ('70kkdajctXSbqSMJbQO424', 'Kacey Musgraves')],
#   'AlbumID': '6PbnGueEO6LGodPfvNldYf',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851e5a25ed08d1e7e0fbb440cef'},
#  {'ID': '3qQbCzHBycnDpGskqOWY0E',
#   'Name': 'Ella Baila Sola',
#   'Duration': '2:45',
#   'Artists': [('0XeEobZplHxzM9QzFQWLiR', 'Eslabon Armado'),
#    ('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma')],
#   'AlbumID': '5aDEezKnOqyQo0qvTFhpkM',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851dfddf1cb31b85a6d28b7d91f'},
#  {'ID': '54zcJnb3tp9c5OVKREZ1Is',
#   'Name': 'MI EX TENÍA RAZÓN',
#   'Duration': '2:34',
#   'Artists': ('790FomKkXshlbRYZFtlgla', 'KAROL G'),
#   'AlbumID': '0FqAaUEyKCyUNFE1uQPZ7i',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851d026bf9d7780f6a1267b4d03'},
#  {'ID': '6uIIdjYTxxpWOyWuVXrKQO',
#   'Name': 'Que Onda',
#   'Duration': '3:11',
#   'Artists': [('6dLuQ5qXxIuWc5urxfIiZR', 'Calle 24'),
#    ('2rmkQLzj0k4nZdQehOUByO', 'Chino Pacas'),
#    ('0ys2OFYzWYB5hRDLCsBqxt', 'Fuerza Regida')],
#   'AlbumID': '4x6cjOcVz44aiLSOHCLKPd',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851c069abd6ab0ed961aa7b2d39'},
#  {'ID': '4lIxdJw6W3Fg4vUIYCB0S5',
#   'Name': 'Style',
#   'Duration': '3:51',
#   'Artists': ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift'),
#   'AlbumID': '2QJmrSgbdM35R67eoGQo4j',
#   'Image': 'https://i.scdn.co/image/ab67616d000048519abdf14e6058bd3903686148'},
#  {'ID': '1p80LdxRV74UKvL8gnD7ky',
#   'Name': 'Blank Space',
#   'Duration': '3:51',
#   'Artists': ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift'),
#   'AlbumID': '2QJmrSgbdM35R67eoGQo4j',
#   'Image': 'https://i.scdn.co/image/ab67616d000048519abdf14e6058bd3903686148'},
#  {'ID': '2N0SPREDYqILVEFSsWF5N5',
#   'Name': 'Love Me Again',
#   'Duration': '3:02',
#   'Artists': ('3JsHnjpbhX4SnySpvpa9DK', 'V'),
#   'AlbumID': '1ZBDI1LqnuAKdrePUF2D5m',
#   'Image': 'https://i.scdn.co/image/ab67616d000048512f1a5b69c2bd76474bca8035'},
#  {'ID': '2i8f4VnnBjy0yDqH2C452a',
#   'Name': 'bad idea right?',
#   'Duration': '3:04',
#   'Artists': ('1McMsnEElThX1knmY4oliG', 'Olivia Rodrigo'),
#   'AlbumID': '3SHq2tBWWsAG6NEOMKZSj0',
#   'Image': 'https://i.scdn.co/image/ab67616d000048518bfab8d577ad17a7b74d9f5f'},
#  {'ID': '6WzRpISELf3YglGAh7TXcG',
#   'Name': 'Popular (with Playboi Carti & Madonna) - Music from the HBO Original Series',
#   'Duration': '3:35',
#   'Artists': [('1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd'),
#    ('699OTQXzgjhIYAHMy9RyPD', 'Playboi Carti'),
#    ('6tbjWDEIzxoDsBA1FuhfPW', 'Madonna')],
#   'AlbumID': '5O0zUvdnJr0RbWzLFneN2i',
#   'Image': 'https://i.scdn.co/image/ab67616d000048514c8f092adc59b4bf4212389d'},
#  {'ID': '6irysuQyZWd7Bjj7ePiOs2',
#   'Name': 'Holanda',
#   'Duration': '3:51',
#   'Artists': ('6nVcHLIgY5pE2YCl8ubca1', 'Jhayco'),
#   'AlbumID': '42D6fdFJ4SLnh4jXZJrsNa',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851cd2ceb6adaa32ecc83cec5c3'},
#  {'ID': '0V3wPSX9ygBnCm8psDIegu',
#   'Name': 'Anti-Hero',
#   'Duration': '3:20',
#   'Artists': ('06HL4z0CvFAxyc27GXpf02', 'Taylor Swift'),
#   'AlbumID': '151w1FgRZfnKZA9FEcg9Z3',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851bb54dde68cd23e2a268ae0f5'},
#  {'ID': '3Ua0m0YmEjrMi9XErKcNiR',
#   'Name': 'Like Crazy',
#   'Duration': '3:32',
#   'Artists': ('1oSPZhvZMIrWW5I41kPkkY', 'Jimin'),
#   'AlbumID': '4xc3Lc9yASZgEJGH7acWMB',
#   'Image': 'https://i.scdn.co/image/ab67616d000048512b46078245d0120690eb560d'},
#  {'ID': '2yzshFeBIwH8tWIqHEFLeD',
#   'Name': 'un x100to',
#   'Duration': '3:14',
#   'Artists': [('6XkjpgcEsYab502Vr1bBeW', 'Grupo Frontera'),
#    ('4q3ewBCX7sLwd24euuV69X', 'Bad Bunny')],
#   'AlbumID': '5i9lMMUZ1QZNsLEE3j50kT',
#   'Image': 'https://i.scdn.co/image/ab67616d0000485150e5306cfaca4f87cd4ecd8d'},
#  {'ID': '2LBqCSwhJGcFQeTHMVGwy3',
#   'Name': 'Die For You',
#   'Duration': '4:20',
#   'Artists': ('1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd'),
#   'AlbumID': '4AdZV63ycxFLF6Hcol0QnB',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851a048415db06a5b6fa7ec4e1a'},
#  {'ID': '7MXVkk9YMctZqd1Srtv4MB',
#   'Name': 'Starboy',
#   'Duration': '3:50',
#   'Artists': [('1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd'),
#    ('4tZwfgrHOc3mvqYlEYSvVi', 'Daft Punk')],
#   'AlbumID': '2ODvWsOgouMbaA5xf0RkJe',
#   'Image': 'https://i.scdn.co/image/ab67616d000048514718e2b124f79258be7bc452'},
#  {'ID': '7K3BhSpAxZBznislvUMVtn',
#   'Name': 'Last Night',
#   'Duration': '2:43',
#   'Artists': ('4oUHIQIBe0LHzYfvXNW4QM', 'Morgan Wallen'),
#   'AlbumID': '6i7mF7whyRJuLJ4ogbH2wh',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851705079df9a25a28b452c1fc9'},
#  {'ID': '7bPp2NmpmyhLJ7zWazAXMu',
#   'Name': 'TULUM',
#   'Duration': '3:29',
#   'Artists': [('12GqGscKJx3aE4t07u7eVZ', 'Peso Pluma'),
#    ('6XkjpgcEsYab502Vr1bBeW', 'Grupo Frontera')],
#   'AlbumID': '4jox3ip1I39DFC2B7R5qLH',
#   'Image': 'https://i.scdn.co/image/ab67616d000048512fb583ed96f8f35cbf2897ba'},
#  {'ID': '41WQUSINanQHfhfKpFDsms',
#   'Name': 'Used To Be Young',
#   'Duration': '3:11',
#   'Artists': ('5YGY8feqx7naU7z4HrwZM6', 'Miley Cyrus'),
#   'AlbumID': '5DvJgsMLbaR1HmAI6VhfcQ',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851cd222052a2594be29a6616b5'},
#  {'ID': '59NraMJsLaMCVtwXTSia8i',
#   'Name': 'Prada',
#   'Duration': '2:12',
#   'Artists': [('5wCmhq5J2hPwL2r0eKurxn', 'cassö'),
#    ('5KKpBU5eC2tJDzf0wmlRp2', 'RAYE'),
#    ('5VadK1havLhK1OpKYsXv9y', 'D-Block Europe')],
#   'AlbumID': '5MU0RmBSpoSxOPYBfcobDc',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851e4b7dccdfd54375ded9ccc5c'},
#  {'ID': '1UMm1Qs3u59Wvk53zBUE8r',
#   'Name': 'SABOR FRESA',
#   'Duration': '2:36',
#   'Artists': ('0ys2OFYzWYB5hRDLCsBqxt', 'Fuerza Regida'),
#   'AlbumID': '1vw6eLxCJRAfD6RMJTiuKZ',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851cfe3eb72c48b93971e53efd9'},
#  {'ID': '7FbrGaHYVDmfr7KoLIZnQ7',
#   'Name': 'Cupid - Twin Ver.',
#   'Duration': '2:54',
#   'Artists': ('4GJ6xDCF5jaUqD6avOuQT6', 'FIFTY FIFTY'),
#   'AlbumID': '5letLUZIFsQikJYShfGNs4',
#   'Image': 'https://i.scdn.co/image/ab67616d0000485137c0b3670236c067c8e8bbcb'},
#  {'ID': '1s7oOCT8vauUh01PbJD6ps',
#   'Name': 'Calm Down (with Selena Gomez)',
#   'Duration': '3:59',
#   'Artists': [('46pWGuE3dSwY3bMMXGBvVS', 'Rema'),
#    ('0C8ZW7ezQVs4URX5aX7Kqx', 'Selena Gomez')],
#   'AlbumID': '0nayxjaX54Frd7GsZq6Pbs',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851963265801aa5c9740ad159b7'},
#  {'ID': '6wsqVwoiVH2kde4k4KKAFU',
#   'Name': 'I KNOW ?',
#   'Duration': '3:31',
#   'Artists': ('0Y5tJX1MQlPlqiwlOH1tJY', 'Travis Scott'),
#   'AlbumID': '18NOKLkZETa4sWwLMIm0UZ',
#   'Image': 'https://i.scdn.co/image/ab67616d00004851881d8d8378cd01099babcd44'},
#  {'ID': '7KA4W4McWYRpgf0fWsJZWB',
#   'Name': 'See You Again (feat. Kali Uchis)',
#   'Duration': '3:00',
#   'Artists': [('4V8LLVI7PbaPR0K2TGSxFF', 'Tyler, The Creator'),
#    ('1U1el3k54VvEUzo3ybLPlM', 'Kali Uchis')],
#   'AlbumID': '2nkto6YNI4rUYTLqEwWJ3o',
#   'Image': 'https://i.scdn.co/image/ab67616d000048518940ac99f49e44f59e6f7fb3'}]

# %%
global_list = [i["ID"] for i in playlist_tracks_global]

# %%
sweden_list = [i["ID"] for i in playlist_tracks_sweden]
sweden_list
# Out:
# ['59NraMJsLaMCVtwXTSia8i',
#  '4o5Ob60pz8QHcFKcr4MWyf',
#  '4c9lx29ADaRI0Hzy8ql69V',
#  '2IGMVunIBsBLtEQyoI1Mu7',
#  '1Rl4O8fqcMTBN8o2rilFBL',
#  '3GygspQIcYy5OnRiw245Qh',
#  '5maA851Fle6XexgJgJzFjF',
#  '2FDTHlrBguDzQkp7PVj16Q',
#  '2cqyU75B4rXPHlU2X6WLCI',
#  '6KOzO2mUwSwe8a9GiJAn7X',
#  '7tHkIqI9XU8qCfLHIzl0pp',
#  '6wf7Yu7cxBSPrRlWeSeK0Q',
#  '3b7YMGle84C9SLNmJC6dz0',
#  '2ZfaBbRMcEgSF8JnJIaEBP',
#  '1VJBnmHm3gUyJnPKetgC3j',
#  '1BxfuPKGuaTgP7aM0Bbdwr',
#  '6HuNgzEw9b4tDcSDCQBS1O',
#  '5LDi79YkHmZ1vRLMlyNlNH',
#  '16jNbcjTGEskPA06R4wbQz',
#  '6y4Z3qrOwInrWJhocyiRcA',
#  '7yfMu3Ez41fQXuD9gUbFjQ',
#  '741UUVE2kuITl0c6zuqqbO',
#  '1vYXt7VSjH9JIM5oRRo7vA',
#  '5GUfpSrOmyK35dOm2LA10V',
#  '1p0RjMued7Tmm0o7CjzoHY',
#  '74xfr2lyWfi2qZjWtqovBg',
#  '4vOoQh9MhS9pyrbvc8LyMz',
#  '4FGvRqZ1pPaflN2jjLBMB9',
#  '1Tx7TwXLu2BQIAz0SRzf2k',
#  '78Du4CMFgnhdlG33gblkiP',
#  '1pLglW5mDscxmbo32uaf3U',
#  '6oEfLCekbv7T0ERha5IQO9',
#  '1odExI7RdWc4BT515LTAwj',
#  '1aEU7mcRDTYBB4ASpqbjYE',
#  '1r5nCkDun9Rg73A5KGWZB0',
#  '56flxHBv6c08oCUjQhXeb1',
#  '3xPsqMJQNM14OrawTBiK4G',
#  '41WQUSINanQHfhfKpFDsms',
#  '2c8wnqPxPUXtxNSJN9b4cS',
#  '3k79jB4aGmMDUQzEwa46Rz',
#  '1RwQZNgaXl01krZHuSUlE8',
#  '2Gd0oV24QsH0zb9nKFx7s5',
#  '5g9gZGiXlk747pESQzmmRT',
#  '4DHcnVTT87F0zZhRPYmZ3B',
#  '2FZax4rYTOkcnG02PrJDzk',
#  '2naSGCjncbz8chvU2qwFzT',
#  '2a6NdKqYB9CaMT2yfiXZnE',
#  '4GK4mydvnsodLEHWb4zJV4',
#  '7wcl1N4Mn1VlBbQQmOlgiO',
#  '544i2kupbLppslcGI1PhlL']

# %%
audio_features_global = get_audio_features(global_list,sp)
audio_features_global
df_global = pd.DataFrame(audio_features_global)
df_global.drop(columns="Track ID", inplace=True)
df_global["Region"]="Global"
df_global
# Out:
#     Danceability  Energy    Tempo  Valence  Region
# 0          0.802  0.8320  124.997    0.890  Global
# 1          0.868  0.5380   99.968    0.732  Global
# 2          0.552  0.7020  169.994    0.564  Global
# 3          0.708  0.7370   91.986    0.607  Global
# 4          0.841  0.7380  169.918    0.484  Global
# 5          0.444  0.0911   78.403    0.142  Global
# 6          0.671  0.8450  110.056    0.775  Global
# 7          0.668  0.7120  100.020    0.264  Global
# 8          0.511  0.5320  137.827    0.322  Global
# 9          0.847  0.6220  130.001    0.220  Global
# 10         0.646  0.7360  140.098    0.873  Global
# 11         0.508  0.4300  130.090    0.324  Global
# 12         0.916  0.5830  141.095    0.661  Global
# 13         0.776  0.8170  149.921    0.515  Global
# 14         0.770  0.5800  144.072    0.753  Global
# 15         0.464  0.4170   67.528    0.479  Global
# 16         0.644  0.7350   88.980    0.418  Global
# 17         0.520  0.7310  173.930    0.662  Global
# 18         0.707  0.6810  117.999    0.646  Global
# 19         0.535  0.3950  157.795    0.488  Global
# 20         0.812  0.4790  169.922    0.559  Global
# 21         0.652  0.8000  143.978    0.234  Global
# 22         0.728  0.4940  105.007    0.558  Global
# 23         0.859  0.6580  100.065    0.672  Global
# 24         0.532  0.6230   89.937    0.403  Global
# 25         0.671  0.8760  129.998    0.964  Global
# 26         0.429  0.4530   77.639    0.155  Global
# 27         0.668  0.7580  147.989    0.834  Global
# 28         0.634  0.7250  159.845    0.795  Global
# 29         0.808  0.9440  124.934    0.937  Global
# 30         0.598  0.7860   95.019    0.456  Global
# 31         0.753  0.6780   96.006    0.583  Global
# 32         0.633  0.6070   74.029    0.363  Global
# 33         0.628  0.8780  129.976    0.796  Global
# 34         0.855  0.6780   99.029    0.852  Global
# 35         0.831  0.7590  107.961    0.244  Global
# 36         0.637  0.6430   97.008    0.533  Global
# 37         0.629  0.7330  120.001    0.362  Global
# 38         0.571  0.7200   83.827    0.542  Global
# 39         0.586  0.5250  133.629    0.508  Global
# 40         0.679  0.5870  186.003    0.486  Global
# 41         0.492  0.6750  203.759    0.478  Global
# 42         0.557  0.8660  167.767    0.631  Global
# 43         0.451  0.6320  147.060    0.455  Global
# 44         0.638  0.7170  141.904    0.422  Global
# 45         0.785  0.8630  130.132    0.962  Global
# 46         0.783  0.5920  120.018    0.726  Global
# 47         0.799  0.8020  107.008    0.811  Global
# 48         0.927  0.6190  117.995    0.817  Global
# 49         0.558  0.5590   78.558    0.620  Global

# %%
audio_features_sweden = get_audio_features(sweden_list,sp)
df_sweden = pd.DataFrame(audio_features_sweden)
df_sweden.drop(columns="Track ID", inplace=True)
df_sweden["Region"]="Sweden"
df_sweden
# Out:
#     Danceability  Energy    Tempo  Valence  Region
# 0          0.638  0.7170  141.904    0.422  Sweden
# 1          0.617  0.5290  165.015    0.501  Sweden
# 2          0.805  0.6230  144.833    0.753  Sweden
# 3          0.868  0.5380   99.968    0.732  Sweden
# 4          0.698  0.8480  105.081    0.689  Sweden
# 5          0.299  0.2340  186.369    0.333  Sweden
# 6          0.743  0.0349   99.969    0.451  Sweden
# 7          0.916  0.5830  141.095    0.661  Sweden
# 8          0.323  0.6140   89.609    0.202  Sweden
# 9          0.721  0.4140  144.758    0.652  Sweden
# 10         0.671  0.5360   98.865    0.733  Sweden
# 11         0.444  0.0911   78.403    0.142  Sweden
# 12         0.691  0.6660   93.014    0.599  Sweden
# 13         0.876  0.6980  130.033    0.850  Sweden
# 14         0.703  0.3690   95.203    0.617  Sweden
# 15         0.552  0.7020  169.994    0.564  Sweden
# 16         0.676  0.4700  105.985    0.155  Sweden
# 17         0.514  0.4530   81.121    0.475  Sweden
# 18         0.955  0.6040  130.037    0.932  Sweden
# 19         0.733  0.8370  150.073    0.933  Sweden
# 20         0.628  0.7830  165.164    0.616  Sweden
# 21         0.770  0.5800  144.072    0.753  Sweden
# 22         0.671  0.8450  110.056    0.775  Sweden
# 23         0.831  0.7850  111.967    0.559  Sweden
# 24         0.627  0.8430  168.011    0.772  Sweden
# 25         0.556  0.6740  208.066    0.447  Sweden
# 26         0.584  0.9150  181.882    0.570  Sweden
# 27         0.562  0.4300  131.737    0.265  Sweden
# 28         0.772  0.7860  124.991    0.859  Sweden
# 29         0.678  0.2640  121.722    0.528  Sweden
# 30         0.636  0.7080  139.829    0.485  Sweden
# 31         0.323  0.0736  146.999    0.266  Sweden
# 32         0.508  0.4300  130.090    0.324  Sweden
# 33         0.655  0.6510   90.054    0.782  Sweden
# 34         0.615  0.5610   79.917    0.302  Sweden
# 35         0.649  0.5520   94.204    0.533  Sweden
# 36         0.833  0.5070  111.031    0.483  Sweden
# 37         0.451  0.6320  147.060    0.455  Sweden
# 38         0.781  0.5920  101.918    0.730  Sweden
# 39         0.511  0.5320  137.827    0.322  Sweden
# 40         0.714  0.7320  179.951    0.720  Sweden
# 41         0.648  0.7330  174.849    0.836  Sweden
# 42         0.779  0.8930  135.071    0.933  Sweden
# 43         0.707  0.6810  117.999    0.646  Sweden
# 44         0.452  0.0690   73.932    0.127  Sweden
# 45         0.667  0.8790  163.921    0.504  Sweden
# 46         0.436  0.6630  200.877    0.466  Sweden
# 47         0.718  0.7020  103.934    0.357  Sweden
# 48         0.662  0.8750  151.985    0.874  Sweden
# 49         0.618  0.5390   95.965    0.109  Sweden

# %%
df_combined = pd.concat([df_global, df_sweden], ignore_index=True)
df_combined
# Out:
#     Danceability  Energy    Tempo  Valence  Region
# 0          0.802   0.832  124.997    0.890  Global
# 1          0.868   0.538   99.968    0.732  Global
# 2          0.552   0.702  169.994    0.564  Global
# 3          0.708   0.737   91.986    0.607  Global
# 4          0.841   0.738  169.918    0.484  Global
# ..           ...     ...      ...      ...     ...
# 95         0.667   0.879  163.921    0.504  Sweden
# 96         0.436   0.663  200.877    0.466  Sweden
# 97         0.718   0.702  103.934    0.357  Sweden
# 98         0.662   0.875  151.985    0.874  Sweden
# 99         0.618   0.539   95.965    0.109  Sweden
#
# [100 rows x 5 columns]

# %%
for attribute in ['Danceability', 'Energy', 'Valence', 'Tempo']:
    sns.boxplot(x='Region', y=attribute, data=df_combined)
    plt.title(f'Comparison of {attribute}')
    plt.show()

# %%
for attribute in ['Danceability', 'Energy', 'Valence', 'Tempo']:
    sns.violinplot(x='Region', y=attribute, data=df_combined)
    plt.title(f'Comparison of {attribute}')
    plt.show()

# %%
for attribute in ['Danceability', 'Energy', 'Valence', 'Tempo']:
    sns.barplot(x='Region', y=attribute, data=df_combined)
    plt.title(f'Comparison of {attribute}')
    plt.show()

# %%
for attribute in ['Danceability', 'Energy', 'Valence', 'Tempo']:
    sns.swarmplot(x='Region', y=attribute, data=df_combined)
    plt.title(f'Comparison of {attribute}')
    plt.show()
